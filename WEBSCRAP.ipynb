# %%
import requests
from bs4 import BeautifulSoup

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
year = '2020'
url_link = 'https://jatim.bps.go.id/statictable/2021/09/14/2284/jumlah-pasangan-usia-subur-dan-peserta-kb-aktif-menurut-kabupaten-kota-di-provinsi-jawa-timur-2020.html'

url = url_link.format(year)
url
# Out:
# 'https://jatim.bps.go.id/statictable/2021/09/14/2284/jumlah-pasangan-usia-subur-dan-peserta-kb-aktif-menurut-kabupaten-kota-di-provinsi-jawa-timur-2020.html'

# %%
years = [2015,2016,2017,2018,2019]
url_link = 'https://jatim.bps.go.id/statictable/2021/09/14/2284/jumlah-pasangan-usia-subur-dan-peserta-kb-aktif-menurut-kabupaten-kota-di-provinsi-jawa-timur-2020.html'

for year in years:
  url = url_link.format(year)
  print(url)
# Out:
# https://jatim.bps.go.id/statictable/2021/09/14/2284/jumlah-pasangan-usia-subur-dan-peserta-kb-aktif-menurut-kabupaten-kota-di-provinsi-jawa-timur-2020.html
# https://jatim.bps.go.id/statictable/2021/09/14/2284/jumlah-pasangan-usia-subur-dan-peserta-kb-aktif-menurut-kabupaten-kota-di-provinsi-jawa-timur-2020.html
# https://jatim.bps.go.id/statictable/2021/09/14/2284/jumlah-pasangan-usia-subur-dan-peserta-kb-aktif-menurut-kabupaten-kota-di-provinsi-jawa-timur-2020.html
# https://jatim.bps.go.id/statictable/2021/09/14/2284/jumlah-pasangan-usia-subur-dan-peserta-kb-aktif-menurut-kabupaten-kota-di-provinsi-jawa-timur-2020.html
# https://jatim.bps.go.id/statictable/2021/09/14/2284/jumlah-pasangan-usia-subur-dan-peserta-kb-aktif-menurut-kabupaten-kota-di-provinsi-jawa-timur-2020.html

# %%
df = pd.read_html(url, header = 0)
df
# Out:
# [Empty DataFrame
#  Columns: [Unnamed: 0, Unnamed: 1]
#  Index: [],
#  Empty DataFrame
#  Columns: [DATA SENSUS, Unnamed: 1]
#  Index: [],
#     Unnamed: 0 Facebook  Unnamed: 2 Instagram
#  0         NaN  Twitter         NaN   Youtube,
#     Unnamed: 0 Berita Resmi Statistik
#  0         NaN              Publikasi,
#     Jumlah Pasangan Usia Subur dan Peserta KB Aktif Menurut Kabupaten/Kota di Provinsi Jawa Timur, 2020  \
#  0   Number of Fertile Age Couples and Active Famil...
#  1                Kabupaten/Kota Regency/ Municipality
#  2                Kabupaten/Kota Regency/ Municipality
#  3                                   Kabupaten/Regency
#  4                                             Pacitan
#  5                                            Ponorogo
#  6                                          Trenggalek
#  7                                         Tulungagung
#  8                                              Blitar
#  9                                              Kediri
# ...

# %%
len(df)
# Out:
# 6

# %%
df[4]
# Out:
#    Jumlah Pasangan Usia Subur dan Peserta KB Aktif Menurut Kabupaten/Kota di Provinsi Jawa Timur, 2020  \
# 0   Number of Fertile Age Couples and Active Famil...
# 1                Kabupaten/Kota Regency/ Municipality
# 2                Kabupaten/Kota Regency/ Municipality
# 3                                   Kabupaten/Regency
# 4                                             Pacitan
# 5                                            Ponorogo
# 6                                          Trenggalek
# 7                                         Tulungagung
# 8                                              Blitar
# 9                                              Kediri
# 10                                             Malang
# 11                                           Lumajang
# 12                                             Jember
# 13                                         Banyuwangi
# 14                                          Bondowoso
# ...
